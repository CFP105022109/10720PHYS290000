# %%
# %matplotlib inline
import matplotlib.image as mpimg
im = mpimg.imread('P1120107.JPG')

import matplotlib.pyplot as plt
plt.imshow(im)

# %%
print(im.shape)
# Out:
# (915, 1220, 3)

# %%
r_im = im[:, :, 0]
plt.imshow(r_im)

# %%
g_im = im[:, :, 1]
plt.imshow(g_im)

# %%
b_im = im[:,:,2]
plt.imshow(b_im)

# %%
plt.imshow(b_im, cmap = "Greys")

# %%
plt.hist(b_im.ravel())
# Out:
# (array([  7891.,  14165.,  15718.,  12426.,  10020.,   8176.,   8859.,
#         270390., 576592., 192063.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(g_im.ravel())
# Out:
# (array([8.61500e+03, 1.44420e+04, 1.62640e+04, 1.47350e+04, 1.84680e+05,
#         5.81656e+05, 2.72367e+05, 2.27130e+04, 5.88000e+02, 2.40000e+02]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
gb_im = g_im+b_im
plt.hist(gb_im.ravel())
# Out:
# (array([  6775.,  13148., 240074., 285664., 314779., 151220.,  78790.,
#          13605.,   6332.,   5913.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
import numpy as np
print(np.mean(b_im))
print(np.median(b_im))
# Out:
# 206.10684403834094
# 213.0
