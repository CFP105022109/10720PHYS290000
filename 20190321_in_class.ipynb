# %%
# %matplotlib inline
import matplotlib.image as mpimg
im1 = mpimg.imread('20190314_224056.jpg')
im2 = mpimg.imread('20190314_224044(0).jpg')
im3 = mpimg.imread('20190314_224044.jpg')
im4 = mpimg.imread('20190314_224045.jpg')
im5 = mpimg.imread('20190314_224046.jpg')

import matplotlib.pyplot as plt
plt.imshow(im1)

# %%
b_im1 = im1[:,:,2]
print (b_im1)
print (b_im1.shape)
# Out:
# [[165 171 170 ... 134 138 141]
#  [168 170 169 ... 138 139 139]
#  [174 174 171 ... 141 139 138]
#  ...
#  [ 91  99 100 ...  73  70  67]
#  [100 102  99 ...  69  67  64]
#  [100  98  93 ...  63  60  58]]
# (1836, 3264)

# %%
import numpy as np
b_im2 = im2[:,:,2]
b_im = np.stack((b_im1, b_im2),axis = 0)
print(b_im.shape)
print(b_im)
# Out:
# (2, 1836, 3264)
# [[[165 171 170 ... 134 138 141]
#   [168 170 169 ... 138 139 139]
#   [174 174 171 ... 141 139 138]
#   ...
#   [ 91  99 100 ...  73  70  67]
#   [100 102  99 ...  69  67  64]
#   [100  98  93 ...  63  60  58]]
#
#  [[215 216 216 ... 189 187 182]
#   [212 215 218 ... 186 186 184]
#   [213 216 218 ... 184 185 186]
#   ...
#   [142 145 145 ...  95  95  95]
#   [144 147 146 ...  97  98  97]
#   [146 148 146 ...  98  97  96]]]

# %%
print (np.mean(b_im))
b_ave = np.mean(b_im, axis = 0)
plt.imshow(b_ave)
# Out:
# 133.1934791039237

# %%
b_im3 = im3[:,:,2]
b_im4 = im4[:,:,2]
b_im5 = im5[:,:,2]
b_im_all = np.stack((b_im1, b_im2, b_im3, b_im4, b_im5),axis = 0)
b_ave_all = np.mean(b_im_all, axis = 0)
plt.imshow(b_ave_all)

# %%
b_med_all = np.median(b_im_all, axis = 0)
plt.imshow(b_med_all)

# %%
im = np.stack((im1, im2, im3, im4, im5),axis = 0)
print(im.shape)
im_ave = np.mean(im_all, axis = 0)
print(im_ave.shape)
print(type(im_ave))
plt.imshow(im_ave.astype(int))
plt.axis('off')
plt.savefig("one_5th_of_SONGSONGMEOW",bbox_inches = "tight",pad_inches = 0)
# Out:
# (5, 1836, 3264, 3)
# (1836, 3264, 3)
# <class 'numpy.ndarray'>

# %%
im_med = np.median(im, axis = 0)
print(im_med.shape)
print(type(im_med))
plt.imshow(im_med.astype(int))
plt.axis('off')
plt.savefig("no_SONGSONGMEOW",bbox_inches = "tight",pad_inches = 0)
# Out:
# (1836, 3264, 3)
# <class 'numpy.ndarray'>
